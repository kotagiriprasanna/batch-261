# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## High Level Sales Analysis

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\sales (1).csv")
df
# Out:
#        Unnamed: 0 prod_id  qty  price  discount member  txn_id  \
# 0               0  c4a632    4     13        17      t  54f307
# 1               1  5d267b    4     40        17      t  54f307
# 2               2  b9a74d    4     17        17      t  54f307
# 3               3  2feb6b    2     29        17      t  54f307
# 4               4  c4a632    5     13        21      t  26cc98
# ...           ...     ...  ...    ...       ...    ...     ...
# 15090       15090  9ec847    1     54        13      t  f15ab3
# 15091       15091  2a2353    3     57        13      t  f15ab3
# 15092       15092  e83aa3    5     32         1      t  93620b
# 15093       15093  d5e9a6    2     23         1      t  93620b
# 15094       15094  5d267b    2     40         1      t  93620b
#
#                  start_txn_time
# 0       2021-02-13 01:59:43.296
# 1       2021-02-13 01:59:43.296
# 2       2021-02-13 01:59:43.296
# 3       2021-02-13 01:59:43.296
# 4      2021-01-19 01:39:00.3456
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15095 entries, 0 to 15094
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      15095 non-null  int64
#  1   prod_id         15095 non-null  object
#  2   qty             15095 non-null  int64
#  3   price           15095 non-null  int64
#  4   discount        15095 non-null  int64
#  5   member          15095 non-null  object
#  6   txn_id          15095 non-null  object
#  7   start_txn_time  15095 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 943.6+ KB

# %%
df.describe(include = 'all')
# Out:
#           Unnamed: 0 prod_id           qty         price      discount member  \
# count   15095.000000   15095  15095.000000  15095.000000  15095.000000  15095
# unique           NaN      12           NaN           NaN           NaN      2
# top              NaN  f084eb           NaN           NaN           NaN      t
# freq             NaN    1281           NaN           NaN           NaN   9061
# mean     7547.000000     NaN      2.995429     28.439218     12.103345    NaN
# std      4357.695492     NaN      1.414698     15.413053      7.053933    NaN
# min         0.000000     NaN      1.000000     10.000000      0.000000    NaN
# 25%      3773.500000     NaN      2.000000     17.000000      6.000000    NaN
# 50%      7547.000000     NaN      3.000000     29.000000     12.000000    NaN
# 75%     11320.500000     NaN      4.000000     40.000000     18.000000    NaN
# max     15094.000000     NaN      5.000000     57.000000     24.000000    NaN
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# prod_id                    0
# qty                        0
# price                      0
# discount                   0
# member                     0
# txn_id                     0
# start_txn_time             0
# revenue                    0
# revenue_before_discount    0
# member_status              0
# transaction_type           0
# total_revenue              0
# dtype: int64

# %%
df2 = pd.read_csv(r"C:\Users\pc\Downloads\product_prices.csv")
df2
# Out:
#     Unnamed: 0  id product_id  price
# 0            0   7     c4a632     13
# 1            1   8     e83aa3     32
# 2            2   9     e31d39     10
# 3            3  10     d5e9a6     23
# 4            4  11     72f5d4     19
# 5            5  12     9ec847     54
# 6            6  13     5d267b     40
# 7            7  14     c8d436     10
# 8            8  15     2a2353     57
# 9            9  16     f084eb     36
# 10          10  17     b9a74d     17
# 11          11  18     2feb6b     29

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12 non-null     int64
#  1   id          12 non-null     int64
#  2   product_id  12 non-null     object
#  3   price       12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 516.0+ bytes

# %%
df2.describe(include = 'all')
# Out:
#         Unnamed: 0         id product_id      price  penetration
# count    12.000000  12.000000         12  12.000000    12.000000
# unique         NaN        NaN         12        NaN          NaN
# top            NaN        NaN     c4a632        NaN          NaN
# freq           NaN        NaN          1        NaN          NaN
# mean      5.500000  12.500000        NaN  28.333333     0.503167
# std       3.605551   3.605551        NaN  16.069923     0.005795
# min       0.000000   7.000000        NaN  10.000000     0.496800
# 25%       2.750000   9.750000        NaN  16.000000     0.498100
# 50%       5.500000  12.500000        NaN  26.000000     0.501600
# 75%       8.250000  15.250000        NaN  37.000000     0.507800
# max      11.000000  18.000000        NaN  57.000000     0.512400

# %%
df2.isna().sum()
# Out:
# Unnamed: 0     0
# id             0
# product_id     0
# price          0
# penetration    0
# dtype: int64

# %%
df3 = pd.read_csv(r"C:\Users\pc\Downloads\product_hierarchy.csv")
df3
# Out:
#     Unnamed: 0  id  parent_id           level_text level_name
# 0            0   1        NaN               Womens   Category
# 1            1   2        NaN                 Mens   Category
# 2            2   3        1.0                Jeans    Segment
# 3            3   4        1.0               Jacket    Segment
# 4            4   5        2.0                Shirt    Segment
# 5            5   6        2.0                Socks    Segment
# 6            6   7        3.0       Navy Oversized      Style
# 7            7   8        3.0       Black Straight      Style
# 8            8   9        3.0        Cream Relaxed      Style
# 9            9  10        4.0           Khaki Suit      Style
# 10          10  11        4.0          Indigo Rain      Style
# 11          11  12        4.0         Grey Fashion      Style
# 12          12  13        5.0            White Tee      Style
# 13          13  14        5.0       Teal Button Up      Style
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18 non-null     int64
#  1   id          18 non-null     int64
#  2   parent_id   16 non-null     float64
#  3   level_text  18 non-null     object
#  4   level_name  18 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 852.0+ bytes

# %%
df3.describe(include = 'all')
# Out:
#         Unnamed: 0         id  parent_id level_text level_name
# count    18.000000  18.000000  16.000000         18         18
# unique         NaN        NaN        NaN         18          3
# top            NaN        NaN        NaN     Womens      Style
# freq           NaN        NaN        NaN          1         12
# mean      8.500000   9.500000   3.750000        NaN        NaN
# std       5.338539   5.338539   1.693123        NaN        NaN
# min       0.000000   1.000000   1.000000        NaN        NaN
# 25%       4.250000   5.250000   2.750000        NaN        NaN
# 50%       8.500000   9.500000   4.000000        NaN        NaN
# 75%      12.750000  13.750000   5.000000        NaN        NaN
# max      17.000000  18.000000   6.000000        NaN        NaN

# %%
df3.isna().sum()
# Out:
# Unnamed: 0    0
# id            0
# parent_id     2
# level_text    0
# level_name    0
# dtype: int64

# %%
df4 = pd.read_csv(r"C:\Users\pc\Downloads\product_details.csv")
df4
# Out:
#     Unnamed: 0 product_id  price                      product_name  \
# 0            0     c4a632     13     Navy Oversized Jeans - Womens
# 1            1     e83aa3     32     Black Straight Jeans - Womens
# 2            2     e31d39     10      Cream Relaxed Jeans - Womens
# 3            3     d5e9a6     23        Khaki Suit Jacket - Womens
# 4            4     72f5d4     19       Indigo Rain Jacket - Womens
# 5            5     9ec847     54      Grey Fashion Jacket - Womens
# 6            6     5d267b     40            White Tee Shirt - Mens
# 7            7     c8d436     10       Teal Button Up Shirt - Mens
# 8            8     2a2353     57            Blue Polo Shirt - Mens
# 9            9     f084eb     36           Navy Solid Socks - Mens
# 10          10     b9a74d     17        White Striped Socks - Mens
# 11          11     2feb6b     29  Pink Fluro Polkadot Socks - Mens
#
#     category_id  segment_id  style_id category_name segment_name  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     12 non-null     int64
#  1   product_id     12 non-null     object
#  2   price          12 non-null     int64
#  3   product_name   12 non-null     object
#  4   category_id    12 non-null     int64
#  5   segment_id     12 non-null     int64
#  6   style_id       12 non-null     int64
#  7   category_name  12 non-null     object
#  8   segment_name   12 non-null     object
#  9   style_name     12 non-null     object
# dtypes: int64(5), object(5)
# memory usage: 1.1+ KB

# %%
df4.describe(include = 'all')
# Out:
#         Unnamed: 0 product_id      price                   product_name  \
# count    12.000000         12  12.000000                             12
# unique         NaN         12        NaN                             12
# top            NaN     c4a632        NaN  Navy Oversized Jeans - Womens
# freq           NaN          1        NaN                              1
# mean      5.500000        NaN  28.333333                            NaN
# std       3.605551        NaN  16.069923                            NaN
# min       0.000000        NaN  10.000000                            NaN
# 25%       2.750000        NaN  16.000000                            NaN
# 50%       5.500000        NaN  26.000000                            NaN
# 75%       8.250000        NaN  37.000000                            NaN
# max      11.000000        NaN  57.000000                            NaN
#
#         category_id  segment_id   style_id category_name segment_name  \
# ...

# %%
df4.isna().sum()
# Out:
# Unnamed: 0       0
# product_id       0
# price            0
# product_name     0
# category_id      0
# segment_id       0
# style_id         0
# category_name    0
# segment_name     0
# style_name       0
# dtype: int64

# %% [markdown]
# ### 1) What was the total quantity sold for all products?

# %%
a = df['qty'].sum()
a
# Out:
# 45216

# %% [markdown]
# ### 2) What is the total generated revenue for all products before discounts?

# %%
x = pd.merge(df, df2[['product_id', 'price']], left_on='prod_id', right_on='product_id', how='left')
df['revenue'] = df['qty'] * df['price']
total_revenue = df['revenue'].sum()
total_revenue
# Out:
# 1289453

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='prod_id', data=df, palette='viridis')
plt.title('Count Plot of Products')
plt.xlabel('Product ID')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 3) What was the total discount amount for all products?

# %%
y = df['discount'].sum()
y
# Out:
# 182700

# %%
# Create a bar plot
plt.bar(['Total Discount'], [total_discount], color='pink')

# Add labels and title
plt.xlabel('Discount')
plt.ylabel('Amount')
plt.title('Total Discount Amount for All Products')

# Show the plot
plt.show()

# %% [markdown]
# ## Transaction Analysis

# %% [markdown]
# ### 1) How many unique transactions were there?

# %%
x = df['txn_id'].unique()
x
# Out:
# array(['54f307', '26cc98', 'ef648d', ..., '72cd63', 'f15ab3', '93620b'],
#       dtype=object)

# %%
x = df['txn_id'].nunique()
x
# Out:
# 2500

# %%
# Creating a count plot
sns.countplot(x='txn_id', data=df)
plt.title(f'Number of Unique Transactions: {unique_transactions_count}')
plt.xlabel('Transaction ID')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2) What is the average unique products purchased in each transaction?

# %%
a = df.groupby('txn_id')['prod_id'].nunique().mean()
a
# Out:
# 6.038

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=average_products_per_transaction)
plt.xlabel('Average Unique Products Purchased per Transaction')
plt.ylabel('Count')
plt.title('Box Plot of Average Unique Products Purchased per Transaction')

plt.show()

# %% [markdown]
# ### 3) What are the 25th, 50th and 75th percentile values for the revenue per transaction?

# %%
df['revenue'] = df['qty'] * df['price']

# Calculate quantiles for revenue per transaction
percentiles = df.groupby('txn_id')['revenue'].sum().quantile([0.25, 0.5, 0.75])

Q1 = percentiles.loc[0.25]
# by using .loc here we re accessing the value at the '25%' label in the percentiles DataFrame.
Q2 = percentiles.loc[0.5]
Q3 = percentiles.loc[0.75]

print("25th Percentile (Q1):", Q1)
print("50th Percentile (Q2/Median):", Q2)
print("75th Percentile (Q3):", Q3)
# Out:
# 25th Percentile (Q1): 375.75
# 50th Percentile (Q2/Median): 509.5
# 75th Percentile (Q3): 647.0

# %%
# Scatter plot
plt.scatter(range(len(revenue_per_transaction)), revenue_per_transaction, label='Revenue per Transaction')
plt.axhline(percentile_values.loc[0.25], color='r', linestyle='--', label='25th Percentile')
plt.axhline(percentile_values.loc[0.50], color='g', linestyle='--', label='50th Percentile (Median)')
plt.axhline(percentile_values.loc[0.75], color='b', linestyle='--', label='75th Percentile')

plt.title('Scatter Plot of Revenue per Transaction with Percentiles')
plt.xlabel('Transaction Index')
plt.ylabel('Revenue per Transaction')
plt.legend()
plt.show()

# %% [markdown]
# ### 4) What is the average discount value per transaction?

# %%
x = df.groupby('txn_id')['discount'].sum().mean()
x
# Out:
# 73.08

# %%
# Create a violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x=average_discount_per_transaction['discount'])

plt.xlabel('Average Discount per Transaction')
plt.ylabel('Frequency')
plt.title('Violin Plot of Average Discount per Transaction')

# Show the plot
plt.show()

# %% [markdown]
# ### 5) What is the percentage split of all transactions for members vs non-members?

# %% [markdown]
# * The eq() method compares each value in a DataFrame to check if it is equal to a specified value, or a value from a specified DataFrame objects, and returns a DataFrame with boolean True/False for each comparison.

# %%
# Assuming 'member' column in the 'df' DataFrame indicates membership status (t for members, f for non-members)

percentage_members = (df['member'].eq('t').mean()) * 100
percentage_non_members = 100 - percentage_members

print("Percentage of transactions by members:", percentage_members, "%")
print("Percentage of transactions by non-members:", percentage_non_members, "%")
# Out:
# Percentage of transactions by members: 60.02649884067572 %
# Percentage of transactions by non-members: 39.97350115932428 %

# %%
plt.figure(figsize=(8, 6))
plt.scatter(percentage_split.index, percentage_split.values, s=100, color=['blue', 'orange'])
plt.title('Percentage Split of Transactions for Members vs. Non-Members')
plt.xlabel('Member Status')
plt.ylabel('Percentage')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your main DataFrame
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# Create a categorical plot (catplot) for the percentage split of members vs non-members
sns.catplot(x="member", kind="count", data=df, palette="pastel", height=6, aspect=1.5)

# Add labels and title
plt.title("Percentage Split of Transactions for Members vs Non-members")
plt.xlabel("Member Status")
plt.ylabel("Number of Transactions")

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 6) What is the average revenue for member transactions and non-member transactions?

# %%
df['revenue'] = df['qty'] * df['price']
average_revenue_member = df[df['member'] == 't']['revenue'].mean()
average_revenue_non_member = df[df['member'] == 'f']['revenue'].mean()

print("Average revenue for member transactions:", average_revenue_member)
print("Average revenue for non-member transactions:", average_revenue_non_member)
# Out:
# Average revenue for member transactions: 85.75035868005739
# Average revenue for non-member transactions: 84.9302287040106

# %%
# Create a boxen plot
plt.figure(figsize=(10, 6))
sns.boxenplot(x='transaction_type', y='price', data=df)
plt.title('Average Revenue for Member and Non-Member Transactions')
plt.xlabel('Transaction Type')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Product Analysis

# %%
df4 = df4.drop(columns=df4.filter(regex='Unnamed: 0').columns, errors='ignore')
df = df.drop(columns=df.filter(regex='Unnamed: 0').columns, errors='ignore')
df3 = df3.drop(columns=df3.filter(regex='Unnamed: 0').columns, errors='ignore')
df2 = df2.drop(columns=df2.filter(regex='Unnamed: 0').columns, errors='ignore')

# Merge the DataFrames based on common columns with suffixes
df5 = pd.merge(df, df4, left_on='prod_id', right_on='product_id', how='left', suffixes=('_sales', '_details'))
df5 = pd.merge(df5, df3, left_on='segment_id', right_on='id', how='left', suffixes=('_sales', '_hierarchy'))
df5 = pd.merge(df5, df2, left_on='prod_id', right_on='product_id', how='left', suffixes=('_sales', '_prices'))
df5
# Out:
#       prod_id  qty  price_sales  discount member  txn_id  \
# 0      c4a632    4           13        17      t  54f307
# 1      5d267b    4           40        17      t  54f307
# 2      b9a74d    4           17        17      t  54f307
# 3      2feb6b    2           29        17      t  54f307
# 4      c4a632    5           13        21      t  26cc98
# ...       ...  ...          ...       ...    ...     ...
# 15090  9ec847    1           54        13      t  f15ab3
# 15091  2a2353    3           57        13      t  f15ab3
# 15092  e83aa3    5           32         1      t  93620b
# 15093  d5e9a6    2           23         1      t  93620b
# 15094  5d267b    2           40         1      t  93620b
#
#                  start_txn_time  revenue  revenue_before_discount  \
# 0       2021-02-13 01:59:43.296       52                       52
# 1       2021-02-13 01:59:43.296      160                      160
# 2       2021-02-13 01:59:43.296       68                       68
# ...

# %% [markdown]
# ### 1. What are the top 3 products by total revenue before discount?

# %%
x = df5.groupby('product_name')['price_sales'].sum().sort_values(ascending=False)
x
# Out:
# product_name
# Blue Polo Shirt - Mens              72276
# Grey Fashion Jacket - Womens        68850
# White Tee Shirt - Mens              50720
# Navy Solid Socks - Mens             46116
# Black Straight Jeans - Womens       39872
# Pink Fluro Polkadot Socks - Mens    36482
# Khaki Suit Jacket - Womens          28681
# Indigo Rain Jacket - Womens         23750
# White Striped Socks - Mens          21131
# Navy Oversized Jeans - Womens       16562
# Cream Relaxed Jeans - Womens        12430
# Teal Button Up Shirt - Mens         12420
# Name: price_sales, dtype: int64

# %%
x.iloc[:3]
# Out:
# product_name
# Blue Polo Shirt - Mens          72276
# Grey Fashion Jacket - Womens    68850
# White Tee Shirt - Mens          50720
# Name: price_sales, dtype: int64

# %%
# Create a box plot for total revenue before discount for the top 3 products
plt.figure(figsize=(10, 6))
boxplot = top_3_df.boxplot(column='total_revenue', by='prod_id', showfliers=False)
plt.title('Box Plot of Total Revenue Before Discount for Top 3 Products')
plt.xlabel('Product ID')
plt.ylabel('Total Revenue Before Discount')
plt.show()

# %% [markdown]
# ### 2. What is the total quantity, revenue and discount for each segment?

# %%
segment_summary = df5.groupby('segment_name').agg({'qty': 'sum', 'price_sales': 'sum', 'discount': 'sum'})
segment_summary
# Out:
#                 qty  price_sales  discount
# segment_name
# Jacket        11385       121281     45452
# Jeans         11349        68864     45740
# Shirt         11265       135416     46043
# Socks         11217       103729     45465

# %%
# stacked bar plot
fig, ax = plt.subplots(figsize=(10, 6))

segment_stats.plot(kind='bar', x='segment_name', y=['qty', 'price_x', 'discount'],
                   stacked=True, ax=ax)

ax.set_ylabel('Count')
ax.set_xlabel('Segment')
ax.set_title('Total Quantity, Revenue, and Discount for Each Segment')

plt.show()

# %%
# Create a catplot using seaborn
plt.figure(figsize=(12, 6))
sns.catplot(x='segment_name', y='Value', hue='Metric', data=melted_data, kind='bar', palette='muted')
plt.title('Total Quantity, Revenue, and Discount for Each Segment')
plt.xlabel('Segment Name')
plt.ylabel('Total')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 3. What is the top selling product for each segment?

# %%
top_selling_product = df5.groupby('segment_name')['product_name'].agg(lambda x: x.value_counts().idxmax())
top_selling_product
# Out:
# segment_name
# Jacket     Grey Fashion Jacket - Womens
# Jeans     Navy Oversized Jeans - Womens
# Shirt            White Tee Shirt - Mens
# Socks           Navy Solid Socks - Mens
# Name: product_name, dtype: object

# %%
# Create a stacked bar plot
fig, ax = plt.subplots(figsize=(10, 6))
colors = plt.cm.tab10.colors

for i, segment in enumerate(top_products_df['segment_name'].unique()):
    segment_data = top_products_df[top_products_df['segment_name'] == segment]
    ax.barh(segment_data['segment_name'], width=1, left=i, color=colors[i], label=segment)
    ax.text(i + 0.5, 0.5, segment_data['product_name'].values[0], ha='center', va='center', color='white', fontweight='bold')

ax.set_xlabel('Segments')
ax.set_title('Top Selling Product for Each Segment')
ax.set_yticks([])
ax.legend()

plt.show()

# %% [markdown]
# ### 4. What is the total quantity, revenue and discount for each category?

# %%
category = df5.groupby('category_name').agg({'qty': 'sum', 'price_sales': 'sum', 'discount': 'sum'})
category
# Out:
#                  qty  price_sales  discount
# category_name
# Mens           22482       239145     91508
# Womens         22734       190145     91192

# %%
# Plotting box plots
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 15))

# Box plot for quantity
axes[0].boxplot(grouped_data['qty'])
axes[0].set_title('Total Quantity by Category')
axes[0].set_ylabel('Quantity')

# Box plot for revenue
axes[1].boxplot(grouped_data['price_x'])
axes[1].set_title('Total Revenue by Category')
axes[1].set_ylabel('Revenue')

# Box plot for discount
axes[2].boxplot(grouped_data['discount'])
axes[2].set_title('Total Discount by Category')
axes[2].set_ylabel('Discount')

plt.tight_layout()
plt.show()

# %%
# Boxen plots for total quantity, revenue, and discount
fig, axes = plt.subplots(3, 1, figsize=(12, 18))

# Boxen plot for total quantity
sns.boxenplot(x='category_name', y='qty', data=merged_df, ax=axes[0])
axes[0].set_title('Total Quantity by Category')

# Boxen plot for total revenue
sns.boxenplot(x='category_name', y='price_x', data=merged_df, ax=axes[1])
axes[1].set_title('Total Revenue by Category')

# Boxen plot for total discount
sns.boxenplot(x='category_name', y='discount', data=merged_df, ax=axes[2])
axes[2].set_title('Total Discount by Category')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.What is the top selling product for each category?

# %%
top_sell_product_by_category = merged_data.groupby('category_name')['product_name'].agg(lambda x: x.value_counts().idxmax())
top_sell_product_by_category
# Out:
# category_name
# Mens           Navy Solid Socks - Mens
# Womens    Grey Fashion Jacket - Womens
# Name: product_name, dtype: object

# %%
# Create a stacked bar plot
fig, ax = plt.subplots(figsize=(10, 6))

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown']

for i, (category, group) in enumerate(top_products_df.groupby('category_name')):
    ax.bar(category, group['qty'], color=colors[i], label=category)

ax.set_xlabel('Category')
ax.set_ylabel('Quantity Sold')
ax.set_title('Top Selling Product in Each Category')
ax.legend()
plt.show()

# %% [markdown]
# ### 6. What is the percentage split of revenue by product for each segment?

# %%
x = df5.groupby(['segment_name','product_name'])['price_sales'].sum()/df5.groupby('segment_name')['price_sales'].sum()*100
x
# Out:
# segment_name  product_name
# Jacket        Grey Fashion Jacket - Womens        56.768991
#               Indigo Rain Jacket - Womens         19.582622
#               Khaki Suit Jacket - Womens          23.648387
# Jeans         Black Straight Jeans - Womens       57.899628
#               Cream Relaxed Jeans - Womens        18.050070
#               Navy Oversized Jeans - Womens       24.050302
# Shirt         Blue Polo Shirt - Mens              53.373309
#               Teal Button Up Shirt - Mens          9.171737
#               White Tee Shirt - Mens              37.454954
# Socks         Navy Solid Socks - Mens             44.458155
#               Pink Fluro Polkadot Socks - Mens    35.170492
#               White Striped Socks - Mens          20.371352
# Name: price_sales, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(percentage_split, cmap='viridis', annot=True, fmt=".2f", linewidths=.5)
plt.title('Percentage Split of Revenue by Product for Each Segment')
plt.xlabel('Product Name')
plt.ylabel('Segment Name')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='segment_name', y='percentage_revenue', data=merged_df)
plt.title('Percentage Split of Revenue by Product for Each Segment')
plt.xlabel('Segment')
plt.ylabel('Percentage Revenue')
plt.show()

# %% [markdown]
# ### 7. What is the percentage split of revenue by segment for each category?

# %%
y = df5.groupby(['category_name','segment_name'])['price_sales'].sum()/df5.groupby('category_name')['price_sales'].sum()*100
y
# Out:
# category_name  segment_name
# Mens           Shirt           56.625060
#                Socks           43.374940
# Womens         Jacket          63.783428
#                Jeans           36.216572
# Name: price_sales, dtype: float64

# %%
# Create a pie chart for each category
categories = revenue_by_category_segment['category_name'].unique()

for category in categories:
    data = revenue_by_category_segment[revenue_by_category_segment['category_name'] == category]
    
    # Plotting the pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(data['price'], labels=data['segment_name'], autopct='%1.1f%%', startangle=140)
    plt.title(f'Revenue Distribution by Segment for {category}')
    plt.show()

# %%
# Create a waterfall chart
fig = go.Figure(go.Waterfall(
    name="",
    orientation="v",
    measure=["absolute"] * len(revenue_by_category_segment),
    x=revenue_by_category_segment['segment_name'],
    textposition="outside",
    text=revenue_by_category_segment['percentage'].apply(lambda x: f"{x:.2f}%"),
    y=revenue_by_category_segment['percentage'],))

fig.update_layout(
    title="Percentage Split of Revenue by Segment for Each Category",
    xaxis_title="Segment",
    yaxis_title="Percentage",
    showlegend=False,)

fig.show()
# Out:
# <div>                            <div id="e287738a-baf3-4f6c-9624-fcceeeabf934" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e287738a-baf3-4f6c-9624-fcceeeabf934")) {                    Plotly.newPlot(                        "e287738a-baf3-4f6c-9624-fcceeeabf934",                        [{"measure":["absolute","absolute","absolute","absolute"],"name":"","orientation":"v","text":["56.87%","43.13%","63.79%","36.21%"],"textposition":"outside","x":["Shirt","Socks","Jacket","Jeans"],"y":[56.873214585783906,43.126785414216094,63.78618991088639,36.21381008911361],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11
# ...

# %% [markdown]
# ### 8. What is the percentage split of total revenue by category?

# %%
z = df5.groupby('category_name')['price_sales'].sum() / df5['price_sales'].sum() * 100
z
# Out:
# category_name
# Mens      55.707098
# Womens    44.292902
# Name: price_sales, dtype: float64

# %%
# box chart
plt.figure(figsize=(10, 6))
percentage_split.sort_values().plot(kind='barh', color='skyblue')
plt.title('Percentage Split of Total Revenue by Category')
plt.xlabel('Percentage (%)')
plt.ylabel('Category')
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
percentage_split.plot(kind='box', vert=False, color='skyblue')
plt.title('Percentage Split of Total Revenue by Category')
plt.xlabel('Percentage')
plt.show()

# %% [markdown]
# ### 9. What is the total transaction “penetration” for each product? (hint: penetration = number of transactions where at least one quantity of a product was purchased divided by total number of transactions)

# %%
a = df5.groupby('product_name')['qty'].apply(lambda x: (x > 0).sum() / len(x))
a
# Out:
# product_name
# Black Straight Jeans - Womens       1.0
# Blue Polo Shirt - Mens              1.0
# Cream Relaxed Jeans - Womens        1.0
# Grey Fashion Jacket - Womens        1.0
# Indigo Rain Jacket - Womens         1.0
# Khaki Suit Jacket - Womens          1.0
# Navy Oversized Jeans - Womens       1.0
# Navy Solid Socks - Mens             1.0
# Pink Fluro Polkadot Socks - Mens    1.0
# Teal Button Up Shirt - Mens         1.0
# White Striped Socks - Mens          1.0
# White Tee Shirt - Mens              1.0
# Name: qty, dtype: float64

# %%
# Plot the count plot
plt.figure(figsize=(8, 4))
sns.barplot(x='product_id', y='penetration', data=df2, palette='viridis')
plt.title('Total Transaction Penetration for Each Product')
plt.xlabel('Product ID')
plt.ylabel('Penetration')
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
penetration.plot(kind='bar', color='skyblue')
plt.title('Total Transaction Penetration for Each Product')
plt.xlabel('Product ID')
plt.ylabel('Penetration')
plt.show()

# %% [markdown]
# ### 10. What is the most common combination of at least 1 quantity of any 3 products in a single transaction?

# %%
com_combination = df5.groupby('txn_id')['product_name'].apply(lambda x: frozenset(x)).value_counts().idxmax()
com_combination
# Out:
# frozenset({'Black Straight Jeans - Womens',
#            'Cream Relaxed Jeans - Womens',
#            'Grey Fashion Jacket - Womens',
#            'Navy Oversized Jeans - Womens',
#            'Navy Solid Socks - Mens',
#            'Pink Fluro Polkadot Socks - Mens',
#            'Teal Button Up Shirt - Mens',
#            'White Tee Shirt - Mens'})

# %%
# Create a donut chart
plt.figure(figsize=(8, 8))
plt.pie(combination_counts, labels=combination_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.gca().add_artist(plt.Circle((0, 0), 0.3, color='white'))  # Draw a white circle to create a donut chart
plt.title('Most Common Combination of at least 1 Quantity of any 3 Products')
plt.show()
